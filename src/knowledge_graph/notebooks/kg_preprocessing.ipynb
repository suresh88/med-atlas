# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("../../../data/output/rxnav_with_fda_with_orig2.xlsx")

# %%
display(df.head())
# Out:
#                     Drug Family  \
# 0  Analgesics - Drugs\nfor Pain
# 1  Analgesics - Drugs\nfor Pain
# 2  Analgesics - Drugs\nfor Pain
# 3  Analgesics - Drugs\nfor Pain
# 4  Analgesics - Drugs\nfor Pain
#
#                                            Drug Name  Drug Tier Notes  \
# 0                acetaminophen\nintravenous solution          1   NaN
# 1                            acetaminophen-\ncodeine          1    QL
# 2  alfentanil hcl\nintravenous solution\n1000 mcg...          1   NaN
# 3                         apap-caff-\ndihydrocodeine          1    QL
# 4                                     ascomp-codeine          1   NaN
#
#   Formulary                                      Match Variant    RxCUI  \
# 0     Optum                 acetaminophen intravenous solution   370506
# 1     Optum                             acetaminophen- codeine   817579
# 2     Optum  alfentanil hcl intravenous solution 1000 mcg/2...  1723206
# 3     Optum                          apap-caff- dihydrocodeine   689569
# 4     Optum                                     ascomp-codeine  1372693
#
#                                   Matched Name  \
# 0                  acetaminophen Oral Solution
# 1                      acetaminophen / codeine
# 2  ALfentanil HCl 500 MCG/ML in 2 ML Injection
# 3    acetaminophen / caffeine / dihydrocodeine
# 4                                          NaN
#
#                                           Brand Name  \
# 0  Bactimicina; Comtrex Sore Throat Relief; Mapap...
# 1                               Tylenol with Codeine
# 2                                                NaN
# 3                                     Dvorah; Trezix
# 4                                             Ascomp
#
#                              Branded Dose Form Group  ...  \
# 0  Anacin AF Oral Product; Bactimicina Oral Liqui...  ...
# 1  Tylenol with Codeine Oral Product; Tylenol wit...  ...
# 2                                                NaN  ...
# 3  Dvorah Oral Product; Dvorah Pill; Trezix Oral ...  ...
# 4                   Ascomp Oral Product; Ascomp Pill  ...
#
#                               search_terms_attempted api_calls_made  \
# 0  ['acetaminophen\nintravenous solution', 'aceta...              1
# 1      ['acetaminophen-\ncodeine', 'acetaminophen-']              1
# 2  ['alfentanil hcl\nintravenous solution\n1000 m...              1
# 3  ['apap-caff-\ndihydrocodeine', 'apap-caff-', '...              2
# 4                                 ['ascomp-codeine']              1
#
#           last_updated orig_application_number  \
# 0  2025-09-03 22:13:46              ANDA207229
# 1  2025-09-03 22:13:46              ANDA207229
# 2  2025-09-03 22:13:47              ANDA075221
# 3  2025-09-03 22:13:48              ANDA040688
# 4  2025-09-03 22:13:48                     NaN
#
#                                     orig_brand_names  \
# 0                                      ACETAMINOPHEN
# 1                                      ACETAMINOPHEN
# 2                                         ALFENTANIL
# 3  ACETAMINOPHEN, CAFFEINE, AND DIHYDROCODEINE BI...
# 4                                                NaN
#
#                                   orig_generic_names orig_submission_type  \
# 0                                      ACETAMINOPHEN                 ORIG
# 1                                      ACETAMINOPHEN                 ORIG
# 2                           ALFENTANIL HYDROCHLORIDE                 ORIG
# 3  ACETAMINOPHEN; CAFFEINE; DIHYDROCODEINE BITART...                 ORIG
# 4                                                NaN                  NaN
#
#   orig_submission_number orig_submission_status orig_approval_date
# 0                    1.0                     AP         2016-11-09
# 1                    1.0                     AP         2016-11-09
# 2                    1.0                     AP         1999-10-28
# 3                    1.0                     AP         2007-04-03
# 4                    NaN                    NaN                NaN
#
# [5 rows x 43 columns]

# %%
import ast
from collections import defaultdict

def merge_dicts_from_string(s):
    """
    Convert a string representation of a list of dicts into
    a single merged dict with deduplicated values.
    """
    if pd.isna(s) or not s.strip():
        return {}
    
    try:
        parsed = ast.literal_eval(s)  # safe parse
    except Exception:
        return {}
    
    merged = defaultdict(list)
    for d in parsed:
        for k, v in d.items():
            for code in v:
                if code not in merged[k]:
                    merged[k].append(code)  # dedup + preserve order
    return dict(merged)

# %%
df["may_treat_diseases_icd10_normalized"] = df["may_treat_diseases_icd10"].apply(merge_dicts_from_string)
display(df.head())
# Out:
#                     Drug Family  \
# 0  Analgesics - Drugs\nfor Pain
# 1  Analgesics - Drugs\nfor Pain
# 2  Analgesics - Drugs\nfor Pain
# 3  Analgesics - Drugs\nfor Pain
# 4  Analgesics - Drugs\nfor Pain
#
#                                            Drug Name  Drug Tier Notes  \
# 0                acetaminophen\nintravenous solution          1   NaN
# 1                            acetaminophen-\ncodeine          1    QL
# 2  alfentanil hcl\nintravenous solution\n1000 mcg...          1   NaN
# 3                         apap-caff-\ndihydrocodeine          1    QL
# 4                                     ascomp-codeine          1   NaN
#
#   Formulary                                      Match Variant    RxCUI  \
# 0     Optum                 acetaminophen intravenous solution   370506
# 1     Optum                             acetaminophen- codeine   817579
# 2     Optum  alfentanil hcl intravenous solution 1000 mcg/2...  1723206
# 3     Optum                          apap-caff- dihydrocodeine   689569
# 4     Optum                                     ascomp-codeine  1372693
#
#                                   Matched Name  \
# 0                  acetaminophen Oral Solution
# 1                      acetaminophen / codeine
# 2  ALfentanil HCl 500 MCG/ML in 2 ML Injection
# 3    acetaminophen / caffeine / dihydrocodeine
# 4                                          NaN
#
#                                           Brand Name  \
# 0  Bactimicina; Comtrex Sore Throat Relief; Mapap...
# 1                               Tylenol with Codeine
# 2                                                NaN
# 3                                     Dvorah; Trezix
# 4                                             Ascomp
#
#                              Branded Dose Form Group  ... api_calls_made  \
# 0  Anacin AF Oral Product; Bactimicina Oral Liqui...  ...              1
# 1  Tylenol with Codeine Oral Product; Tylenol wit...  ...              1
# 2                                                NaN  ...              1
# 3  Dvorah Oral Product; Dvorah Pill; Trezix Oral ...  ...              2
# 4                   Ascomp Oral Product; Ascomp Pill  ...              1
#
#           last_updated orig_application_number  \
# 0  2025-09-03 22:13:46              ANDA207229
# 1  2025-09-03 22:13:46              ANDA207229
# 2  2025-09-03 22:13:47              ANDA075221
# 3  2025-09-03 22:13:48              ANDA040688
# 4  2025-09-03 22:13:48                     NaN
#
#                                     orig_brand_names  \
# 0                                      ACETAMINOPHEN
# 1                                      ACETAMINOPHEN
# 2                                         ALFENTANIL
# 3  ACETAMINOPHEN, CAFFEINE, AND DIHYDROCODEINE BI...
# 4                                                NaN
#
#                                   orig_generic_names orig_submission_type  \
# 0                                      ACETAMINOPHEN                 ORIG
# 1                                      ACETAMINOPHEN                 ORIG
# 2                           ALFENTANIL HYDROCHLORIDE                 ORIG
# 3  ACETAMINOPHEN; CAFFEINE; DIHYDROCODEINE BITART...                 ORIG
# 4                                                NaN                  NaN
#
#   orig_submission_number orig_submission_status orig_approval_date  \
# 0                    1.0                     AP         2016-11-09
# 1                    1.0                     AP         2016-11-09
# 2                    1.0                     AP         1999-10-28
# 3                    1.0                     AP         2007-04-03
# 4                    NaN                    NaN                NaN
#
#                  may_treat_diseases_icd10_normalized
# 0  {'Fever': ['A78', 'A79.0', 'A93.1', 'A96.2', '...
# 1  {'Fever': ['A78', 'A79.0', 'A93.1', 'A96.2', '...
# 2                                                 {}
# 3  {'Cough': ['R05.1', 'R05.2', 'R05.3', 'R05.4',...
# 4  {'Arthritis, Rheumatoid': ['M06.9', 'M06.88', ...
#
# [5 rows x 44 columns]

# %%
print(df['may_treat_diseases_icd10_normalized'][0])
# Out:
# {'Fever': ['A78', 'A79.0', 'A93.1', 'A96.2', 'R50.82', 'R50.83', 'R50.9', 'A01.00', 'A01.1', 'A01.2', 'A01.3', 'A01.4', 'A38.9', 'A48.4', 'A68.9', 'A75.9', 'A77.9', 'A91', 'A92.2', 'A92.4'], 'Pain': ['N50.82', 'R07.2', 'R07.82', 'R10.13', 'R10.33', 'R14.1', 'R52', 'R68.84', 'G50.1', 'G89.0', 'G89.29', 'G89.4', 'H57.13', 'N50.811', 'N50.812', 'N50.819', 'R07.0', 'R07.89', 'R07.9', 'R10.84']}

# %%
def extract_icd10_prefix_by_key(d):
    """
    Given a dict like {'Pain': ['R07.2', 'R07.82'], 'Anxiety': ['F41.9']},
    return {'Pain': ['R07'], 'Anxiety': ['F41']}.
    """
    if not isinstance(d, dict):
        return {}

    result = {}
    for k, codes in d.items():
        prefixes = set()
        for code in codes:
            prefixes.add(code.split(".")[0])  # take prefix before "."
        result[k] = sorted(prefixes)  # keep unique & sorted
    return result


# Apply on dataframe column
df["may_treat_diseases_icd10_normalized"] = df["may_treat_diseases_icd10_normalized"].apply(extract_icd10_prefix_by_key)

# %%
display(df.head())
# Out:
#                     Drug Family  \
# 0  Analgesics - Drugs\nfor Pain
# 1  Analgesics - Drugs\nfor Pain
# 2  Analgesics - Drugs\nfor Pain
# 3  Analgesics - Drugs\nfor Pain
# 4  Analgesics - Drugs\nfor Pain
#
#                                            Drug Name  Drug Tier Notes  \
# 0                acetaminophen\nintravenous solution          1   NaN
# 1                            acetaminophen-\ncodeine          1    QL
# 2  alfentanil hcl\nintravenous solution\n1000 mcg...          1   NaN
# 3                         apap-caff-\ndihydrocodeine          1    QL
# 4                                     ascomp-codeine          1   NaN
#
#   Formulary                                      Match Variant    RxCUI  \
# 0     Optum                 acetaminophen intravenous solution   370506
# 1     Optum                             acetaminophen- codeine   817579
# 2     Optum  alfentanil hcl intravenous solution 1000 mcg/2...  1723206
# 3     Optum                          apap-caff- dihydrocodeine   689569
# 4     Optum                                     ascomp-codeine  1372693
#
#                                   Matched Name  \
# 0                  acetaminophen Oral Solution
# 1                      acetaminophen / codeine
# 2  ALfentanil HCl 500 MCG/ML in 2 ML Injection
# 3    acetaminophen / caffeine / dihydrocodeine
# 4                                          NaN
#
#                                           Brand Name  \
# 0  Bactimicina; Comtrex Sore Throat Relief; Mapap...
# 1                               Tylenol with Codeine
# 2                                                NaN
# 3                                     Dvorah; Trezix
# 4                                             Ascomp
#
#                              Branded Dose Form Group  ... api_calls_made  \
# 0  Anacin AF Oral Product; Bactimicina Oral Liqui...  ...              1
# 1  Tylenol with Codeine Oral Product; Tylenol wit...  ...              1
# 2                                                NaN  ...              1
# 3  Dvorah Oral Product; Dvorah Pill; Trezix Oral ...  ...              2
# 4                   Ascomp Oral Product; Ascomp Pill  ...              1
#
#           last_updated orig_application_number  \
# 0  2025-09-03 22:13:46              ANDA207229
# 1  2025-09-03 22:13:46              ANDA207229
# 2  2025-09-03 22:13:47              ANDA075221
# 3  2025-09-03 22:13:48              ANDA040688
# 4  2025-09-03 22:13:48                     NaN
#
#                                     orig_brand_names  \
# 0                                      ACETAMINOPHEN
# 1                                      ACETAMINOPHEN
# 2                                         ALFENTANIL
# 3  ACETAMINOPHEN, CAFFEINE, AND DIHYDROCODEINE BI...
# 4                                                NaN
#
#                                   orig_generic_names orig_submission_type  \
# 0                                      ACETAMINOPHEN                 ORIG
# 1                                      ACETAMINOPHEN                 ORIG
# 2                           ALFENTANIL HYDROCHLORIDE                 ORIG
# 3  ACETAMINOPHEN; CAFFEINE; DIHYDROCODEINE BITART...                 ORIG
# 4                                                NaN                  NaN
#
#   orig_submission_number orig_submission_status orig_approval_date  \
# 0                    1.0                     AP         2016-11-09
# 1                    1.0                     AP         2016-11-09
# 2                    1.0                     AP         1999-10-28
# 3                    1.0                     AP         2007-04-03
# 4                    NaN                    NaN                NaN
#
#                  may_treat_diseases_icd10_normalized
# 0  {'Fever': ['A01', 'A38', 'A48', 'A68', 'A75', ...
# 1  {'Fever': ['A01', 'A38', 'A48', 'A68', 'A75', ...
# 2                                                 {}
# 3  {'Cough': ['A37', 'G44', 'J45', 'R05'], 'Pain'...
# 4  {'Arthritis, Rheumatoid': ['M06', 'M08'], 'Fev...
#
# [5 rows x 44 columns]

# %%
print(df['may_treat_diseases_icd10_normalized'][0])
# Out:
# {'Fever': ['A01', 'A38', 'A48', 'A68', 'A75', 'A77', 'A78', 'A79', 'A91', 'A92', 'A93', 'A96', 'R50'], 'Pain': ['G50', 'G89', 'H57', 'N50', 'R07', 'R10', 'R14', 'R52', 'R68']}

# %% [raw]
# If the ICD-10 codes are continues then combine them.
# Example:
# Input: {'Heroin Dependence': ['F10', 'F11', 'F12', 'F14', 'F15', 'F16', 'F17', 'F18', 'T40', 'Z99'], 'Pain': ['G50', 'G89', 'H57', 'N50', 'R07', 'R10', 'R14', 'R52', 'R68']}
# Output: {'Heroin Dependence': ['F10-F12', 'F14-F18', 'T40', 'Z99'], 'Pain': ['G50', 'G89', 'H57', 'N50', 'R07', 'R10', 'R14', 'R52', 'R68']}

# %%
import re
import pandas as pd

def _normalize_prefix_dict(d):
    """
    Ensure each key maps to a unique, ordered list of non-empty string prefixes.
    """
    if not isinstance(d, dict):
        return {}

    out = {}
    for k, vals in d.items():
        seen = set()
        cleaned = []
        for v in vals or []:
            if not isinstance(v, str):
                continue
            v = v.strip().upper()
            if not v:
                continue
            if v not in seen:
                seen.add(v)
                cleaned.append(v)
        out[k] = cleaned
    return out

def combine_continuous_icd10(d):
    """
    For each key, merge consecutive ICD-10 prefixes with the same letter(s):
      F10, F11, F12 -> F10-F12
    Non-consecutive codes remain as-is (e.g., T40, Z99).
    """
    if not isinstance(d, dict):
        return {}

    result = {}
    for k, codes in d.items():
        # parse (letters, number) for sortable grouping; keep unknowns as passthrough
        parsed = []
        passthrough = []
        for code in codes:
            m = re.match(r"^([A-Z]+)(\d+)$", code)
            if m:
                letter, num = m.groups()
                parsed.append((letter, int(num)))
            else:
                # If it doesn't match LETTER+NUMBER (e.g., 'U07', 'X99A'), keep as-is
                passthrough.append(code)

        # sort by (letter, number)
        parsed.sort(key=lambda x: (x[0], x[1]))

        compressed = []
        i = 0
        while i < len(parsed):
            letter, start_num = parsed[i]
            end_num = start_num
            j = i + 1
            # grow range while consecutive within same letter group
            while j < len(parsed) and parsed[j][0] == letter and parsed[j][1] == end_num + 1:
                end_num = parsed[j][1]
                j += 1

            if start_num == end_num:
                compressed.append(f"{letter}{start_num}")
            else:
                compressed.append(f"{letter}{start_num}-{letter}{end_num}")

            i = j

        # keep original non-LETTER+NUMBER items in their original relative order at the end
        result[k] = compressed + passthrough

    return result

# ---- Apply row-wise on your DataFrame column ----
# df['icd10_prefix_dict'] should already exist from your previous step
df["may_treat_diseases_icd10_normalized"] = (
    df["may_treat_diseases_icd10_normalized"]
      .apply(_normalize_prefix_dict)
      .apply(combine_continuous_icd10)
)

# Optional: inspect one row
# print(df["icd10_prefix_ranges"].iloc[0])

# %%
display(df.head())
# Out:
#                     Drug Family  \
# 0  Analgesics - Drugs\nfor Pain
# 1  Analgesics - Drugs\nfor Pain
# 2  Analgesics - Drugs\nfor Pain
# 3  Analgesics - Drugs\nfor Pain
# 4  Analgesics - Drugs\nfor Pain
#
#                                            Drug Name  Drug Tier Notes  \
# 0                acetaminophen\nintravenous solution          1   NaN
# 1                            acetaminophen-\ncodeine          1    QL
# 2  alfentanil hcl\nintravenous solution\n1000 mcg...          1   NaN
# 3                         apap-caff-\ndihydrocodeine          1    QL
# 4                                     ascomp-codeine          1   NaN
#
#   Formulary                                      Match Variant    RxCUI  \
# 0     Optum                 acetaminophen intravenous solution   370506
# 1     Optum                             acetaminophen- codeine   817579
# 2     Optum  alfentanil hcl intravenous solution 1000 mcg/2...  1723206
# 3     Optum                          apap-caff- dihydrocodeine   689569
# 4     Optum                                     ascomp-codeine  1372693
#
#                                   Matched Name  \
# 0                  acetaminophen Oral Solution
# 1                      acetaminophen / codeine
# 2  ALfentanil HCl 500 MCG/ML in 2 ML Injection
# 3    acetaminophen / caffeine / dihydrocodeine
# 4                                          NaN
#
#                                           Brand Name  \
# 0  Bactimicina; Comtrex Sore Throat Relief; Mapap...
# 1                               Tylenol with Codeine
# 2                                                NaN
# 3                                     Dvorah; Trezix
# 4                                             Ascomp
#
#                              Branded Dose Form Group  ... api_calls_made  \
# 0  Anacin AF Oral Product; Bactimicina Oral Liqui...  ...              1
# 1  Tylenol with Codeine Oral Product; Tylenol wit...  ...              1
# 2                                                NaN  ...              1
# 3  Dvorah Oral Product; Dvorah Pill; Trezix Oral ...  ...              2
# 4                   Ascomp Oral Product; Ascomp Pill  ...              1
#
#           last_updated orig_application_number  \
# 0  2025-09-03 22:13:46              ANDA207229
# 1  2025-09-03 22:13:46              ANDA207229
# 2  2025-09-03 22:13:47              ANDA075221
# 3  2025-09-03 22:13:48              ANDA040688
# 4  2025-09-03 22:13:48                     NaN
#
#                                     orig_brand_names  \
# 0                                      ACETAMINOPHEN
# 1                                      ACETAMINOPHEN
# 2                                         ALFENTANIL
# 3  ACETAMINOPHEN, CAFFEINE, AND DIHYDROCODEINE BI...
# 4                                                NaN
#
#                                   orig_generic_names orig_submission_type  \
# 0                                      ACETAMINOPHEN                 ORIG
# 1                                      ACETAMINOPHEN                 ORIG
# 2                           ALFENTANIL HYDROCHLORIDE                 ORIG
# 3  ACETAMINOPHEN; CAFFEINE; DIHYDROCODEINE BITART...                 ORIG
# 4                                                NaN                  NaN
#
#   orig_submission_number orig_submission_status orig_approval_date  \
# 0                    1.0                     AP         2016-11-09
# 1                    1.0                     AP         2016-11-09
# 2                    1.0                     AP         1999-10-28
# 3                    1.0                     AP         2007-04-03
# 4                    NaN                    NaN                NaN
#
#                  may_treat_diseases_icd10_normalized
# 0  {'Fever': ['A1', 'A38', 'A48', 'A68', 'A75', '...
# 1  {'Fever': ['A1', 'A38', 'A48', 'A68', 'A75', '...
# 2                                                 {}
# 3  {'Cough': ['A37', 'G44', 'J45', 'R5'], 'Pain':...
# 4  {'Arthritis, Rheumatoid': ['M6', 'M8'], 'Fever...
#
# [5 rows x 44 columns]

# %%
df['may_treat_diseases_icd10_normalized'][6]
# Out:
# {'Heroin Dependence': ['F10-F12', 'F14-F18', 'T40', 'Z99'],
#  'Pain': ['G50', 'G89', 'H57', 'N50', 'R7', 'R10', 'R14', 'R52', 'R68']}

# %%
df.shape
# Out:
# (500, 44)

# %%
df.to_excel("../../../data/output/rxnav_with_kg.xlsx", index = False)
